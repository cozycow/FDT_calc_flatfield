# %%
import fnmatch
from connect import bob

sftp = bob()

top_dir = '/data/solo/phi/data/fmdb/l1/'
dirs = sorted(sftp.listdir(top_dir))

folder = '/home/ulyanov/data/solo/phi/2026/'

for directory in dirs:
    if fnmatch.fnmatch(directory, '2025-11*'):
        for file in sorted(sftp.listdir(top_dir + directory)):
            if fnmatch.fnmatch(file, '*fdt-alam*C_*.fits.gz'):
                print(file)

                remote_file = top_dir + directory + '/' + file
                local_file = folder + file

                sftp.get(remote_file, local_file)
# Out:
# solo_L1_phi-fdt-alam_20251102T002003_V202604242325C_0551020501.fits.gz
# solo_L1_phi-fdt-alam_20251102T062003_V202604242325C_0551020502.fits.gz
# solo_L1_phi-fdt-alam_20251102T122003_V202604242325C_0551020503.fits.gz
# solo_L1_phi-fdt-alam_20251102T182003_V202604242325C_0551020504.fits.gz
# solo_L1_phi-fdt-alam_20251103T004003_V202604242336C_0551030501.fits.gz
# solo_L1_phi-fdt-alam_20251103T062003_V202604242336C_0551030502.fits.gz
# solo_L1_phi-fdt-alam_20251103T122003_V202604242336C_0551030503.fits.gz
# solo_L1_phi-fdt-alam_20251103T182003_V202604242337C_0551030504.fits.gz
# solo_L1_phi-fdt-alam_20251104T002003_V202604242348C_0551040501.fits.gz
# solo_L1_phi-fdt-alam_20251104T062002_V202604242348C_0551040502.fits.gz
# solo_L1_phi-fdt-alam_20251104T122003_V202604242348C_0551040503.fits.gz
# solo_L1_phi-fdt-alam_20251104T182003_V202604242349C_0551040504.fits.gz
# solo_L1_phi-fdt-alam_20251105T002003_V202604242358C_0551050501.fits.gz
# solo_L1_phi-fdt-alam_20251105T062003_V202604242358C_0551050502.fits.gz
# solo_L1_phi-fdt-alam_20251105T122003_V202604242359C_0551050503.fits.gz
# solo_L1_phi-fdt-alam_20251105T182003_V202604242359C_0551050504.fits.gz
# solo_L1_phi-fdt-alam_20251106T002003_V202604250011C_0551060501.fits.gz
# solo_L1_phi-fdt-alam_20251106T062003_V202604250011C_0551060502.fits.gz
# solo_L1_phi-fdt-alam_20251106T122003_V202604250011C_0551060503.fits.gz
# solo_L1_phi-fdt-alam_20251106T182003_V202604250011C_0551060504.fits.gz
# solo_L1_phi-fdt-alam_20251107T010003_V202604250022C_0551070501.fits.gz
# solo_L1_phi-fdt-alam_20251107T062003_V202604250022C_0551070502.fits.gz
# solo_L1_phi-fdt-alam_20251107T122003_V202604250022C_0551070503.fits.gz
# solo_L1_phi-fdt-alam_20251107T182003_V202604250022C_0551070504.fits.gz
# solo_L1_phi-fdt-alam_20251108T002003_V202604250033C_0551080501.fits.gz
# solo_L1_phi-fdt-alam_20251108T062003_V202604250033C_0551080502.fits.gz
# solo_L1_phi-fdt-alam_20251108T113003_V202604250033C_0551080503.fits.gz
# solo_L1_phi-fdt-alam_20251108T182003_V202604250033C_0551080504.fits.gz
# solo_L1_phi-fdt-alam_20251109T002003_V202604250043C_0551090501.fits.gz
# solo_L1_phi-fdt-alam_20251109T062003_V202604250043C_0551090502.fits.gz
# solo_L1_phi-fdt-alam_20251109T122003_V202604250043C_0551090503.fits.gz
# solo_L1_phi-fdt-alam_20251109T182003_V202604250043C_0551090504.fits.gz
# solo_L1_phi-fdt-alam_20251110T032003_V202604250052C_0551100501.fits.gz
# solo_L1_phi-fdt-alam_20251110T033505_V202604250052C_0551100502.fits.gz
# solo_L1_phi-fdt-alam_20251110T035005_V202604250052C_0551100503.fits.gz
# solo_L1_phi-fdt-alam_20251110T070003_V202604250052C_0551100504.fits.gz
# solo_L1_phi-fdt-alam_20251110T071505_V202604250158C_0551100505.fits.gz
# solo_L1_phi-fdt-alam_20251110T073005_V202604250159C_0551100506.fits.gz
# solo_L1_phi-fdt-alam_20251110T092003_V202604250159C_0551100507.fits.gz
# solo_L1_phi-fdt-alam_20251110T093505_V202604250159C_0551100508.fits.gz
# solo_L1_phi-fdt-alam_20251110T095005_V202604250159C_0551100509.fits.gz
# solo_L1_phi-fdt-alam_20251110T122003_V202604250200C_0551100510.fits.gz
# solo_L1_phi-fdt-alam_20251110T123505_V202604250200C_0551100511.fits.gz
# solo_L1_phi-fdt-alam_20251110T125006_V202604250200C_0551100512.fits.gz
# solo_L1_phi-fdt-alam_20251110T152003_V202604250200C_0551100513.fits.gz
# solo_L1_phi-fdt-alam_20251110T153505_V202604250200C_0551100514.fits.gz
# solo_L1_phi-fdt-alam_20251110T155005_V202604250200C_0551100515.fits.gz
# solo_L1_phi-fdt-alam_20251110T182003_V202604250201C_0551100516.fits.gz
# solo_L1_phi-fdt-alam_20251110T183505_V202604250201C_0551100517.fits.gz
# solo_L1_phi-fdt-alam_20251110T185005_V202604250201C_0551100518.fits.gz
# solo_L1_phi-fdt-alam_20251111T002003_V202604250100C_0551110501.fits.gz
# solo_L1_phi-fdt-alam_20251111T003505_V202604250100C_0551110502.fits.gz
# solo_L1_phi-fdt-alam_20251111T005005_V202604250100C_0551110503.fits.gz
# solo_L1_phi-fdt-alam_20251111T032003_V202604250100C_0551110504.fits.gz
# solo_L1_phi-fdt-alam_20251111T033505_V202604250156C_0551110505.fits.gz
# solo_L1_phi-fdt-alam_20251111T035005_V202604250156C_0551110506.fits.gz
# solo_L1_phi-fdt-alam_20251111T062004_V202604250156C_0551110507.fits.gz
# solo_L1_phi-fdt-alam_20251111T063506_V202604250156C_0551110508.fits.gz
# solo_L1_phi-fdt-alam_20251111T065006_V202604250156C_0551110509.fits.gz
# solo_L1_phi-fdt-alam_20251111T092003_V202604250157C_0551110510.fits.gz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp_client.py:799, in SFTPClient.getfo(self, remotepath, fl, callback, prefetch, max_concurrent_prefetch_requests)
#     798     fr.prefetch(file_size, max_concurrent_prefetch_requests)
# --> 799 return self._transfer_with_callback(
#     800     reader=fr, writer=fl, file_size=file_size, callback=callback
#     801 )
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp_client.py:678, in SFTPClient._transfer_with_callback(self, reader, writer, file_size, callback)
#     677 while True:
# --> 678     data = reader.read(32768)
#     679     writer.write(data)
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/file.py:203, in BufferedFile.read(self, size)
#     202 try:
# --> 203     new_data = self._read(read_size)
#     204 except EOFError:
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp_file.py:182, in SFTPFile._read(self, size)
#     181 if self._prefetching:
# --> 182     data = self._read_prefetch(size)
#     183     if data is not None:
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp_file.py:162, in SFTPFile._read_prefetch(self, size)
#     161     break
# --> 162 self.sftp._read_response()
#     163 self._check_exception()
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp_client.py:887, in SFTPClient._read_response(self, waitfor)
#     886 try:
# --> 887     t, data = self._read_packet()
#     888 except EOFError as e:
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp.py:218, in BaseSFTP._read_packet(self)
#     217 size = struct.unpack(">I", x)[0]
# --> 218 data = self._read_all(size)
#     219 if self.ultra_debug:
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp.py:196, in BaseSFTP._read_all(self, n)
#     195 else:
# --> 196     x = self.sock.recv(n)
#     198 if len(x) == 0:
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/channel.py:697, in Channel.recv(self, nbytes)
#     696 try:
# --> 697     out = self.in_buffer.read(nbytes, self.timeout)
#     698 except PipeTimeout:
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/buffered_pipe.py:150, in BufferedPipe.read(self, nbytes, timeout)
#     149 then = time.time()
# --> 150 self._cv.wait(timeout)
#     151 if timeout is not None:
#
# File ~/miniconda3/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     326 if timeout is None:
# --> 327     waiter.acquire()
#     328     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# SFTPError                                 Traceback (most recent call last)
# Cell In[2], line 20
#      17 remote_file = top_dir + directory + '/' + file
#      18 local_file = folder + file
# ---> 20 sftp.get(remote_file, local_file)
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp_client.py:840, in SFTPClient.get(self, remotepath, localpath, callback, prefetch, max_concurrent_prefetch_requests)
#     811 """
#     812 Copy a remote file (``remotepath``) from the SFTP server to the local
#     813 host as ``localpath``.  Any exception raised by operations will be
#    (...)
#     837     Added ``max_concurrent_prefetch_requests``.
#     838 """
#     839 with open(localpath, "wb") as fl:
# --> 840     size = self.getfo(
#     841         remotepath,
#     842         fl,
#     843         callback,
#     844         prefetch,
#     845         max_concurrent_prefetch_requests,
#     846     )
#     847 s = os.stat(localpath)
#     848 if s.st_size != size:
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp_client.py:796, in SFTPClient.getfo(self, remotepath, fl, callback, prefetch, max_concurrent_prefetch_requests)
#     769 """
#     770 Copy a remote file (``remotepath``) from the SFTP server and write to
#     771 an open file or file-like object, ``fl``.  Any exception raised by
#    (...)
#     793     Added ``max_concurrent_prefetch_requests``.
#     794 """
#     795 file_size = self.stat(remotepath).st_size
# --> 796 with self.open(remotepath, "rb") as fr:
#     797     if prefetch:
#     798         fr.prefetch(file_size, max_concurrent_prefetch_requests)
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/util.py:289, in ClosingContextManager.__exit__(self, type, value, traceback)
#     288 def __exit__(self, type, value, traceback):
# --> 289     self.close()
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp_file.py:82, in SFTPFile.close(self)
#      78 def close(self):
#      79     """
#      80     Close the file.
#      81     """
# ---> 82     self._close(async_=False)
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp_file.py:104, in SFTPFile._close(self, async_)
#     102         self.sftp._async_request(type(None), CMD_CLOSE, self.handle)
#     103     else:
# --> 104         self.sftp._request(CMD_CLOSE, self.handle)
#     105 except EOFError:
#     106     # may have outlived the Transport connection
#     107     pass
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp_client.py:857, in SFTPClient._request(self, t, *args)
#     855 def _request(self, t, *args):
#     856     num = self._async_request(type(None), t, *args)
# --> 857     return self._read_response(num)
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp_client.py:887, in SFTPClient._read_response(self, waitfor)
#     885 while True:
#     886     try:
# --> 887         t, data = self._read_packet()
#     888     except EOFError as e:
#     889         raise SSHException("Server connection dropped: {}".format(e))
#
# File ~/miniconda3/lib/python3.11/site-packages/paramiko/sftp.py:216, in BaseSFTP._read_packet(self)
#     213 # most sftp servers won't accept packets larger than about 32k, so
#     214 # anything with the high byte set (> 16MB) is just garbage.
#     215 if byte_ord(x[0]):
# --> 216     raise SFTPError("Garbage packet received")
#     217 size = struct.unpack(">I", x)[0]
#     218 data = self._read_all(size)
#
# SFTPError: Garbage packet received
