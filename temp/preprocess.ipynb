# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt

from processing import process
import glob
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.

# %%
dark_file = '/home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz'
deadpix_file = '/home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits'
prefilter_file = '/home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt'
distortion_file = '/home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz'

# %%
folders = sorted(glob.glob('/home/ulyanov/data/solo/phi/flat/fdt/calibration/*'))
folders
# Out:
# ['/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-09-26',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-16',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-27',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-12-02',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25']

# %%
folder = folders[6]
files = sorted(glob.glob(folder + '/*'))
files
# Out:
# ['/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T080009_V202503131733C_0563100100.fits.gz',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T080608_V202503131733C_0563100125.fits.gz',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T081208_V202503131835C_0563100150.fits.gz',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T081808_V202503131935C_0563100175.fits.gz',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T082408_V202503131935C_0563100200.fits.gz',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T083008_V202503132033C_0563100225.fits.gz',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T083608_V202503141634C_0563100250.fits.gz',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T084208_V202503141734C_0563100275.fits.gz',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T084808_V202503141833C_0563100300.fits.gz']

# %%
for file in files[:1]:
    data, header = process(file,
                           dark_file=dark_file,
                           deadpix_file=deadpix_file,
                           prefilter_file=prefilter_file,
                           distortion_file=distortion_file,
                           _find_center=True)

# %%
from classical_estimates import get_wv_shift

shift = get_wv_shift(data, header)
# Out:
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:48: RuntimeWarning: invalid value encountered in divide
#   shift[i * mx: (i + 1) * mx, j * my: (j + 1) * my] = np.mean(temp_[:-1] * np.expand_dims(wv_, axis=(1,2)), axis=0) / np.mean(temp_[:-1], axis=0)

# %%
plt.figure(figsize=(10,10))
plt.imshow(shift, vmin=-0.05, vmax=0.05)
plt.tight_layout()
