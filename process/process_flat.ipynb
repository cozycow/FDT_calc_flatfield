# %%
from calc_flatfield import calc_flatfield
import glob

# %%
dark_file = '/home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz'
deadpix_file = '/home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits'
prefilter_file = '/home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt'
distortion_file = '/home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz'

# %%
folders = sorted(glob.glob('/home/ulyanov/data/solo/phi/flat/fdt/calibration/*'))
folders
# Out:
# ['/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-09-26',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-16',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-27',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-12-02',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25']

# %%
folder = folders[0]

# %%
calc_flatfield(folder, 'temp',
               dark_file=dark_file,
               deadpix_file=deadpix_file,
               prefilter_file=prefilter_file,
               distortion_file=distortion_file,
               niter=100,
               quicklook=True)
# Out:
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30/solo_L1_phi-fdt-ilam_20240330T050009_V202604251526C_0463300100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30/solo_L1_phi-fdt-ilam_20240330T054806_V202604251535C_0463300300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/lib/python3.11/site-packages/astropy/io/fits/file.py:435, in _File.readarray(self, size, offset, dtype, shape)
#     434 self._file.seek(offset)
# --> 435 data = _array_from_file(self._file, dtype, count)
#     436 return data.reshape(shape)
#
# File ~/miniconda3/lib/python3.11/site-packages/astropy/io/fits/util.py:534, in _array_from_file(infile, dtype, count)
#     533 read_size = np.dtype(dtype).itemsize * count
# --> 534 s = infile.read(read_size)
#     535 array = np.ndarray(buffer=s, dtype=dtype, shape=(count,))
#
# File ~/miniconda3/lib/python3.11/gzip.py:301, in GzipFile.read(self, size)
#     300     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 301 return self._buffer.read(size)
#
# File ~/miniconda3/lib/python3.11/_compression.py:68, in DecompressReader.readinto(self, b)
#      67 with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68     data = self.read(len(byte_view))
#      69     byte_view[:len(data)] = data
#
# File ~/miniconda3/lib/python3.11/gzip.py:507, in _GzipReader.read(self, size)
#     505 buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
# --> 507 uncompress = self._decompressor.decompress(buf, size)
#     508 if self._decompressor.unconsumed_tail != b"":
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 calc_flatfield(folder, 'temp',
#       2                dark_file=dark_file,
#       3                deadpix_file=deadpix_file,
#       4                prefilter_file=prefilter_file,
#       5                distortion_file=distortion_file,
#       6                niter=100,
#       7                quicklook=True)
#
# File ~/PycharmProjects/flatfield/src/calc_flatfield.py:67, in calc_flatfield(files, folder_out, dark_file, deadpix_file, prefilter_file, distortion_file, niter, quicklook, verbose)
#      64 centers = []
#      66 for i, file in enumerate(files):
# ---> 67     data, header = preprocess(file,
#      68                               dark_file=dark_file,
#      69                               deadpix_file=deadpix_file,
#      70                               prefilter_file=prefilter_file,
#      71                               distortion_file=distortion_file,
#      72                               true_continuum=True,
#      73                               calc_dc=True,
#      74                               verbose=verbose)
#      76     if i == 0:
#      77         header_ = header
#
# File ~/PycharmProjects/flatfield/src/preprocess.py:26, in preprocess(file, dark_file, prefilter_file, cavity_file, flatfield_file, deadpix_file, ghost_file, distortion_file, true_continuum, calc_dc, folder_out, to_file, verbose)
#      11 def preprocess(file,
#      12                dark_file=None,
#      13                prefilter_file=None,
#    (...)
#      22                to_file=False,
#      23                verbose=True):
#      25     with fits.open(file) as hdul:
# ---> 26         data = hdul[0].data
#      27         header_data = hdul[0].header
#      28         img_data = hdul['PHI_FITS_imageSummary'].data
#
# File ~/miniconda3/lib/python3.11/site-packages/astropy/utils/decorators.py:949, in lazyproperty.__get__(self, obj, owner)
#     947         val = obj_dict.get(self._key, _NotFound)
#     948         if val is _NotFound:
# --> 949             val = self.fget(obj)
#     950             obj_dict[self._key] = val
#     951 return val
#
# File ~/miniconda3/lib/python3.11/site-packages/astropy/io/fits/hdu/image.py:245, in _ImageBaseHDU.data(self)
#     242 if len(self._axes) < 1:
#     243     return
# --> 245 data = self._get_scaled_image_data(self._data_offset, self.shape)
#     246 self._update_header_scale_info(data.dtype)
#     248 return data
#
# File ~/miniconda3/lib/python3.11/site-packages/astropy/io/fits/hdu/image.py:799, in _ImageBaseHDU._get_scaled_image_data(self, offset, shape)
#     792 """
#     793 Internal function for reading image data from a file and apply scale
#     794 factors to it.  Normally this is used for the entire image, but it
#     795 supports alternate offset/shape for Section support.
#     796 """
#     797 code = BITPIX2DTYPE[self._orig_bitpix]
# --> 799 raw_data = self._get_raw_data(shape, code, offset)
#     800 raw_data = raw_data.view(raw_data.dtype.newbyteorder(">"))
#     802 return self._scale_data(raw_data)
#
# File ~/miniconda3/lib/python3.11/site-packages/astropy/io/fits/hdu/base.py:552, in _BaseHDU._get_raw_data(self, shape, code, offset)
#     550     return np.ndarray(shape, dtype=code, buffer=self._buffer, offset=offset)
#     551 elif self._file:
# --> 552     return self._file.readarray(offset=offset, dtype=code, shape=shape)
#     553 else:
#     554     return None
#
# File ~/miniconda3/lib/python3.11/site-packages/astropy/io/fits/file.py:444, in _File.readarray(self, size, offset, dtype, shape)
#     437 finally:
#     438     # Make sure we leave the file in the position we found it; on
#     439     # some platforms (e.g. Windows) mmaping a file handle can also
#     440     # reset its file pointer.
#     441     # Also for Windows when using mmap seek() may return weird
#     442     # negative values, which is fixed by calling tell() before.
#     443     self._file.tell()
# --> 444     self._file.seek(filepos)
#
# File ~/miniconda3/lib/python3.11/gzip.py:393, in GzipFile.seek(self, offset, whence)
#     391 elif self.mode == READ:
#     392     self._check_not_closed()
# --> 393     return self._buffer.seek(offset, whence)
#     395 return self.offset
#
# File ~/miniconda3/lib/python3.11/_compression.py:153, in DecompressReader.seek(self, offset, whence)
#     151 # Read and discard data until we reach the desired position.
#     152 while offset > 0:
# --> 153     data = self.read(min(io.DEFAULT_BUFFER_SIZE, offset))
#     154     if not data:
#     155         break
#
# File ~/miniconda3/lib/python3.11/gzip.py:507, in _GzipReader.read(self, size)
#     504 # Read a chunk of data from the file
#     505 buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
# --> 507 uncompress = self._decompressor.decompress(buf, size)
#     508 if self._decompressor.unconsumed_tail != b"":
#     509     self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:

# %%
for folder in folders:

    calc_flatfield(folder, 'temp',
                   dark_file=dark_file,
                   deadpix_file=deadpix_file,
                   prefilter_file=prefilter_file,
                   distortion_file=distortion_file,
                   niter=100,
                   quicklook=True)
