# %%
from calc_flatfield import calc_flatfield
import glob

# %%
dark_file = '/home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz'
deadpix_file = '/home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits'
prefilter_file = '/home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt'
distortion_file = '/home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz'

# %%
folders = sorted(glob.glob('/home/ulyanov/data/solo/phi/flat/fdt/calibration/*'))
folders
# Out:
# ['/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-09-26',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-16',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-27',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-12-02',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25']

# %%
folder = folders[-5]

# %%
calc_flatfield(folder, 'temp',
               dark_file=dark_file,
               deadpix_file=deadpix_file,
               prefilter_file=prefilter_file,
               distortion_file=distortion_file,
               niter=100,
               quicklook=False)
# Out:
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T080009_V202503131733C_0563100100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T084808_V202503141833C_0563100300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.50961276 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 56 C
# continuum position is: red
# wavelengths are: [6172.752 6172.821 6172.891 6172.961 6173.03  6173.187] A
# disk centers are: [[ 993.4271 1033.2214]
#  [ 890.0036  951.8804]
#  [ 947.8227  997.0763]
#  [1024.982  1057.6441]
#  [1170.6863 1171.5818]
#  [ 912.6642 1136.9089]
#  [ 958.0412 1079.222 ]
#  [1019.2081 1002.0436]
#  [1133.1719  856.5334]]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 979.8185913374084 978.7473705756497
# calculating instrumental polarization
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:277: RuntimeWarning: divide by zero encountered in divide
#   G = (a * v - b * u) / (a * d - b ** 2)
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:287: RuntimeWarning: divide by zero encountered in divide
#   F = a / b
# removing fringes
# removing ghosts from data and recalculating transmittance
# normalizing transmittance
# transmittance norm is: 1.0200768
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20250310T080009_V202608181157C_0563100100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20250310T080009_V202608181157C_0563100100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20250310T080009_V202608181157C_0563100100.fits
# done

# %%
for folder in folders:

    calc_flatfield(folder, 'temp',
                   dark_file=dark_file,
                   deadpix_file=deadpix_file,
                   prefilter_file=prefilter_file,
                   distortion_file=distortion_file,
                   niter=100,
                   quicklook=True)
# Out:
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30/solo_L1_phi-fdt-ilam_20240330T050009_V202604251526C_0463300100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30/solo_L1_phi-fdt-ilam_20240330T054806_V202604251535C_0463300300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.3131228 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 56 C
# continuum position is: red
# wavelengths are: [6172.9   6172.97  6173.039 6173.108 6173.177 6173.335] A
# disk centers are: [[ 994.6271 1036.7501]
#  [ 825.9005  904.0141]
#  [ 919.8194  977.7279]
#  [1046.0981 1076.8833]
#  [1283.2727 1262.8412]
#  [ 862.1389 1206.0265]
#  [ 935.6909 1112.0448]
#  [1034.8942  985.619 ]
#  [1221.3193  748.327 ]]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 998.4687756178748 995.1363158154453
# calculating instrumental polarization
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:287: RuntimeWarning: divide by zero encountered in divide
#   F = a / b
# removing fringes
# removing ghosts from data and recalculating transmittance
# /home/ulyanov/PycharmProjects/flatfield/src/kll.py:64: RuntimeWarning: divide by zero encountered in divide
#   return np.nan_to_num(A / B)
# normalizing transmittance
# transmittance norm is: 1.0323103877303106
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20240330T050009_V202608191814C_0463300100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20240330T050009_V202608191814C_0463300100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20240330T050009_V202608191814C_0463300100.fits
# making quicklook image
# quicklook image saved to file: temp/phi-fdt-ilam_20240330T050009_V202608191814C_0463300100.png
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-09-26
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-09-26/solo_L1_phi-fdt-ilam_20240926T114503_V202604251703C_0469260100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-09-26/solo_L1_phi-fdt-ilam_20240926T123308_V202604251709C_0469260300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.30912373 AU
# PMP SP temperature is: 45 C
# FG SP temperature is:
]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 996.0638416719695 995.4601271414997
# calculating instrumental polarization
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:287: RuntimeWarning: divide by zero encountered in divide
#   F = a / b
# removing fringes
# removing ghosts from data and recalculating transmittance
# normalizing transmittance
# transmittance norm is: 1.030492346742426
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20250923T000503_V202608192115C_0569230100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20250923T000503_V202608192115C_0569230100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20250923T000503_V202608192115C_0569230100.fits
# making quicklook image
# quicklook image saved to file: temp/phi-fdt-ilam_20250923T000503_V202608192115C_0569230100.png
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T040003_V202606241235C_0663100100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T043205_V202606241634C_0663100300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.32765725 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 66 C
# continuum position is: blue
# wavelengths are: [6173.378 6173.536 6173.605 6173.674 6173.744 6173.813] A
# disk centers are: [[ 996.4147 1048.7939]
#  [ 834.6398  921.7749]
#  [ 924.4161  992.0585]
#  [1044.9526 1086.6406]
#  [1271.6741 1264.2967]
#  [ 869.5087 1209.9097]
#  [ 940.2686 1120.3276]
#  [1035.1371  999.7214]
#  [1212.7992  772.9213]]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 995.1656549154875 996.8821964427267
# calculating instrumental polarization
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:287: RuntimeWarning: divide by zero encountered in divide
#   F = a / b
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:288: RuntimeWarning: invalid value encountered in multiply
#   W = I / np.abs(Q - F * I - G * I_).clip(sigma)
# removing fringes
# removing ghosts from data and recalculating transmittance
# normalizing transmittance
# transmittance norm is: 1.02711266636842
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20260310T040003_V202608192138C_0663100100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20260310T040003_V202608192138C_0663100100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20260310T040003_V202608192138C_0663100100.fits
# making quicklook image
# quicklook image saved to file: temp/phi-fdt-ilam_20260310T040003_V202608192138C_0663100100.png
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T230003_V202605051433C_0664250100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T233204_V202605201634C_0664250300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.80967238 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 61 C
# continuum position is: blue
# wavelengths are: [6173.254 6173.412 6173.481 6173.551 6173.621 6173.69 ] A
# disk centers are: [[ 999.7177 1039.7714]
#  [ 934.3059  988.3422]
#  [ 970.6268 1016.9565]
#  [1019.2718 1054.9824]
#  [1111.214  1126.8979]
#  [ 948.7445 1104.9382]
#  [ 977.4781 1068.5874]
#  [1015.6394 1019.7628]
#  [1087.1068  928.4059]]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 971.4979499095234 976.9455999657164
# calculating instrumental polarization
# removing fringes
# removing ghosts from data and recalculating transmittance
# normalizing transmittance
# transmittance norm is: 1.0087569680143416
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20260425T230003_V202608192201C_0664250100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20260425T230003_V202608192201C_0664250100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20260425T230003_V202608192201C_0664250100.fits
# making quicklook image
# quicklook image saved to file: temp/phi-fdt-ilam_20260425T230003_V202608192201C_0664250100.png
# done
