# %%
from calc_flatfield import calc_flatfield
import glob

# %%
dark_file = '/home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz'
deadpix_file = '/home/ulyanov/data/solo/phi/dead_pixels/phi-fdt-deadpix_20250915T140003_V202609041457C_0569150100.fits'
prefilter_file = '/home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt'
distortion_file = '/home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz'

# %%
folders = sorted(glob.glob('/home/ulyanov/data/solo/phi/flat/fdt/calibration/*'))[::-1]
folders
# Out:
# ['/home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-12-02',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-27',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-16',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-09-26',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30']

# %%
for folder in folders:

    calc_flatfield(folder, 'temp',
                   dark_file=dark_file,
                   deadpix_file=deadpix_file,
                   prefilter_file=prefilter_file,
                   distortion_file=distortion_file,
                   niter=100,
                   quicklook=True)
# Out:
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T230003_V202605051433C_0664250100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T233204_V202605201634C_0664250300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.80967238 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 61 C
# continuum position is: blue
# wavelengths are: [6173.254 6173.412 6173.481 6173.551 6173.621 6173.69 ] A
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: divide by zero encountered in divide
#   data_ /= data_[contpos]
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: invalid value encountered in divide
#   data_ /= data_[contpos]
# disk centers are: [[ 999.7177 1039.7714]
#  [ 934.3059  988.3422]
#  [ 970.6268 1016.9565]
#  [1019.2718 1054.9824]
#  [1111.214  1126.8979]
#  [ 948.7445 1104.9382]
#  [ 977.4781 1068.5874]
#  [1015.6394 1019.7628]
#  [1087.1068  928.4059]]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 971.4938628394204 976.846358032454
# calculating instrumental polarization
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:332: RuntimeWarning: divide by zero encountered in divide
#   F = a / b
# removing fringes
# removing ghosts from data and recalculating transmittance
# normalizing transmittance
# transmittance norm is: 1.008829125753559
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20260425T230003_V202608261804C_0664250100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20260425T230003_V202608261804C_0664250100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20260425T230003_V202608261804C_0664250100.fits
# making quicklook image
# quicklook image saved to file: temp/phi-fdt-ilam_20260425T230003_V202608261804C_0664250100.png
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T040003_V202606241235C_0663100100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T043205_V202606241634C_0663100300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.32765725 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 66 C
# continuum position is: blue
# wavelengths are: [6173.378 6173.536 6173.605 6173.674 6173.744 6173.813] A
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: divide by zero encountered in divide
#   data_ /= data_[contpos]
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: invalid value encountered in divide
#   data_ /= data_[contpos]
# disk centers are: [[ 996.4147 1048.7939]
#  [ 834.6403  921.7749]
#  [ 924.4161  992.0585]
#  [1044.9526 1086.6406]
#  [1271.6866 1264.3187]
#  [ 869.5087 1209.9097]
#  [ 940.2686 1120.3276]
#  [1035.1371  999.7214]
#  [1212.8016  772.9205]]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 995.4604472719877 996.4380868287692
# calculating instrumental polarization
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:332: RuntimeWarning: divide by zero encountered in divide
#   F = a / b
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:333: RuntimeWarning: invalid value encountered in multiply
#   W = I / np.abs(Q - F * I - G * I_).clip(sigma)
# removing fringes
# removing ghosts from data and recalculating transmittance
# normalizing transmittance
# transmittance norm is: 1.0272871577532263
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20260310T040003_V202608261828C_0663100100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20260310T040003_V202608261828C_0663100100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20260310T040003_V202608261828C_0663100100.fits
# making quicklook image
# quicklook image saved to file: temp/phi-fdt-ilam_20260310T040003_V202608261828C_0663100100.png
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T000503_V202512011636C_0569230100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T005305_V202511220034C_0569230300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.33117085 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 66 C
# continuum position is: blue
# wavelengths are: [6173.391 6173.548 6173.618 6173.687 6173.756 6173.826] A
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: divide by zero encountered in divide
#   data_ /= data_[contpos]
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: invalid value encountered in divide
#   data_ /= data_[contpos]
# disk centers are: [[1005.4378 1043.5406]
#  [ 845.1491  917.9965]
#  [ 934.5464  988.2163]
#  [1054.3504 1082.1297]
#  [1277.9739 1257.5559]
#  [ 880.0976 1203.7803]
#  [ 949.8945 1114.9075]
#  [1043.6963  995.6041]
#  [1219.3874  771.8324]]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 996.1240124101319 995.1194072624073
# calculating instrumental polarization
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:332: RuntimeWarning: divide by zero encountered in divide
#   F = a / b
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:333: RuntimeWarning: invalid value encountered in multiply
#   W = I / np.abs(Q - F * I - G * I_).clip(sigma)
# removing fringes
# removing ghosts from data and recalculating transmittance
# normalizing transmittance
# transmittance norm is: 1.030559407310037
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20250923T000503_V202608261853C_0569230100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20250923T000503_V202608261853C_0569230100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20250923T000503_V202608261853C_0569230100.fits
# making quicklook image
# quicklook image saved to file: temp/phi-fdt-ilam_20250923T000503_V202608261853C_0569230100.png
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T140003_V202511211337C_0569150100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T144807_V202511212307C_0569150300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.29446903 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 61 C
# continuum position is: blue
# wavelengths are: [6173.011 6173.17  6173.239 6173.309 6173.376 6173.446] A
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: divide by zero encountered in divide
#   data_ /= data_[contpos]
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning
ountered in divide
#   data_ /= data_[contpos]
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: invalid value encountered in divide
#   data_ /= data_[contpos]
# disk centers are: [[ 996.4641 1032.9258]
#  [ 906.8196  962.5372]
#  [ 956.9158 1001.6908]
#  [1023.384  1054.0162]
#  [1148.0304 1152.0359]
#  [ 925.8492 1121.8742]
#  [ 965.2114 1072.2873]
#  [1017.8504 1005.887 ]]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 976.2780074636737 977.6702605774258
# calculating instrumental polarization
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:332: RuntimeWarning: divide by zero encountered in divide
#   F = a / b
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:333: RuntimeWarning: invalid value encountered in multiply
#   W = I / np.abs(Q - F * I - G * I_).clip(sigma)
# removing fringes
# removing ghosts from data and recalculating transmittance
# normalizing transmittance
# transmittance norm is: 1.0151327466503353
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20241027T233003_V202608262048C_0470270100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20241027T233003_V202608262048C_0470270100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20241027T233003_V202608262048C_0470270100.fits
# making quicklook image
# quicklook image saved to file: temp/phi-fdt-ilam_20241027T233003_V202608262048C_0470270100.png
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-16
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-16/solo_L1_phi-fdt-ilam_20241016T113003_V202604260024C_0470160100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-16/solo_L1_phi-fdt-ilam_20241016T120203_V202604260029C_0470160300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.44202536 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 66 C
# continuum position is: blue
# wavelengths are: [6173.545 6173.704 6173.773 6173.843 6173.913 6173.981] A
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: divide by zero encountered in divide
#   data_ /= data_[contpos]
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: invalid value encountered in divide
#   data_ /= data_[contpos]
# disk centers are: [[ 992.2863 1036.3789]
#  [ 872.5305  942.3339]
#  [ 939.4208  994.7555]
#  [1028.8954 1064.8925]
#  [1196.4962 1196.4147]
#  [ 898.5102 1156.1428]
#  [ 951.1225 1089.332 ]
#  [1021.0241  999.9296]
#  [1152.4259  832.168 ]]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 984.0988189404598 986.4281226940307
# calculating instrumental polarization
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:332: RuntimeWarning: divide by zero encountered in divide
#   F = a / b
# removing fringes
# removing ghosts from data and recalculating transmittance
# normalizing transmittance
# transmittance norm is: 1.0206490912212476
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20241016T113003_V202608262111C_0470160100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20241016T113003_V202608262111C_0470160100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20241016T113003_V202608262111C_0470160100.fits
# making quicklook image
# quicklook image saved to file: temp/phi-fdt-ilam_20241016T113003_V202608262111C_0470160100.png
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-09-26
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-09-26/solo_L1_phi-fdt-ilam_20240926T114503_V202604251703C_0469260100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-09-26/solo_L1_phi-fdt-ilam_20240926T123308_V202604251709C_0469260300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.30912373 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 56 C
# continuum position is: blue
# wavelengths are: [6172.766 6172.925 6172.995 6173.063 6173.133 6173.202] A
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: divide by zero encountered in divide
#   data_ /= data_[contpos]
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: invalid value encountered in divide
#   data_ /= data_[contpos]
# disk centers are: [[1006.5086 1044.2064]
#  [ 834.2966  909.4465]
#  [ 929.6816  984.3334]
#  [1057.9025 1084.9418]
#  [1298.3031 1273.4203]
#  [ 871.3397 1215.071 ]
#  [ 946.4442 1119.6908]
#  [1046.8142  991.1893]
#  [1235.027   750.8976]]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 999.190036576044 999.5924626905478
# calculating instrumental polarization
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:332: RuntimeWarning: divide by zero encountered in divide
#   F = a / b
# removing fringes
# removing ghosts from data and recalculating transmittance
# /home/ulyanov/PycharmProjects/flatfield/src/kll.py:64: RuntimeWarning: divide by zero encountered in divide
#   return np.nan_to_num(A / B)
# normalizing transmittance
# transmittance norm is: 1.031168584929453
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20240926T114503_V202608262134C_0469260100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20240926T114503_V202608262134C_0469260100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20240926T114503_V202608262134C_0469260100.fits
# making quicklook image
# quicklook image saved to file: temp/phi-fdt-ilam_20240926T114503_V202608262134C_0469260100.png
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30/solo_L1_phi-fdt-ilam_20240330T050009_V202604251526C_0463300100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30/solo_L1_phi-fdt-ilam_20240330T054806_V202604251535C_0463300300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.3131228 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 56 C
# continuum position is: red
# wavelengths are: [6172.9   6172.97  6173.039 6173.108 6173.177 6173.335] A
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: divide by zero encountered in divide
#   data_ /= data_[contpos]
# /home/ulyanov/PycharmProjects/flatfield/src/classical_estimates.py:42: RuntimeWarning: invalid value encountered in divide
#   data_ /= data_[contpos]
# /home/ulyanov/miniconda3/lib/python3.11/site-packages/numpy/_core/_methods.py:132: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# disk centers are: [[ 994.6271 1036.7501]
#  [ 825.9017  904.0131]
#  [ 919.8194  977.7279]
#  [1046.0981 1076.8833]
#  [1283.275  1262.8449]
#  [ 862.1389 1206.0256]
#  [ 935.6909 1112.0448]
#  [1034.8942  985.619 ]
#  [1221.3181  748.3277]]
# calculating mask
# calculating cavity
# calculating transmittance
# correcting data for transmittance
# realigning and demodulating the data
# modulation matrix is:
# [[ 1.0023  -0.64814 -0.56202 -0.51859]
#  [ 1.0041   0.54693 -0.55299  0.633  ]
#  [ 0.99523  0.46132  0.54165 -0.69603]
#  [ 0.99838 -0.61944  0.66189  0.42519]]
# calculating ghost reflection center
# reflection center is: 998.682221641721 995.1984420747963
# calculating instrumental polarization
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:332: RuntimeWarning: divide by zero encountered in divide
#   F = a / b
# /home/ulyanov/PycharmProjects/flatfield/src/calc_flatfield.py:333: RuntimeWarning: invalid value encountered in multiply
#   W = I / np.abs(Q - F * I - G * I_).clip(sigma)
# removing fringes
# removing ghosts from data and recalculating transmittance
# normalizing transmittance
# transmittance norm is: 1.0322929241082086
# modulating flatfield
# filling missing values
# distorting flatfield
# saving result
# flatfield map saved to file: temp/phi-fdt-flat_20240330T050009_V202608262158C_0463300100.fits
# ghost map saved to file: temp/phi-fdt-ghost_20240330T050009_V202608262158C_0463300100.fits
# cavity map saved to file: temp/phi-fdt-cavity_20240330T050009_V202608262158C_0463300100.fits
# making quicklook image
# quicklook image saved to file: temp/phi-fdt-ilam_20240330T050009_V202608262158C_0463300100.png
# done

# %%
folder = folders[-1]

# %%
calc_flatfield(folder, 'temp',
               dark_file=dark_file,
               deadpix_file=deadpix_file,
               prefilter_file=prefilter_file,
               distortion_file=distortion_file,
               niter=100,
               quicklook=False)
# Out:
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30/solo_L1_phi-fdt-ilam_20240330T050009_V202604251526C_0463300100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30/solo_L1_phi-fdt-ilam_20240330T054806_V202604251535C_0463300300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/PHI_deadpix_maskcorrected.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 calc_flatfield(folder, 'temp',
#       2                dark_file=dark_file,
#       3                deadpix_file=deadpix_file,
#       4                prefilter_file=prefilter_file,
#       5                distortion_file=distortion_file,
#       6                niter=100,
#       7                quicklook=False)
#
# File ~/PycharmProjects/flatfield/src/calc_flatfield.py:71, in calc_flatfield(files, folder_out, dark_file, deadpix_file, prefilter_file, distortion_file, niter, quicklook, verbose)
#      68 centers = []
#      70 for i, file in enumerate(files):
# ---> 71     data, header = process(file,
#      72                            dark_file=dark_file,
#      73                            deadpix_file=deadpix_file,
#      74                            prefilter_file=prefilter_file,
#      75                            distortion_file=distortion_file,
#      76                            _find_center=True,
#      77                            verbose=verbose)
#      79     if i == 0:
#      80         header_ = header
#
# File ~/PycharmProjects/flatfield/src/processing.py:67, in process(file, dark_file, prefilter_file, cavity_file, flatfield_file, deadpix_file, ghost_file, distortion_file, _find_center, _realign, _demodulate, _correct_fringes, _correct_crosstalk, folder_out, to_file, verbose)
#      64     data = data / crop(flat, header_data)
#      66 if prefilter_file is not None:
# ---> 67     data = correct_prefilter(data, header_data, prefilter_file)
#      69 if ghost_file is not None:
#      70     with fits.open(ghost_file) as hdul:
#
# File ~/PycharmProjects/flatfield/src/prefilter_correction.py:39, in correct_prefilter(data, header, prefilter_file, temperature_constant, cavity_map, **kwargs)
#      36 delta_wv = (temperature - prefilter_temperature) * temperature_constant
#      37 prefilter_wavelengths += delta_wv
# ---> 39 prefilter = interpolate_prefilter(coefficients, prefilter_wavelengths, wavelengths, cavity=cavity_map, header=header)
#      40 data_ = data.copy().reshape((nwv, -1, nx, ny))
#      41 data_ /= np.expand_dims(prefilter, 1)
#
# File ~/PycharmProjects/flatfield/src/prefilter_correction.py:117, in interpolate_prefilter(coeff, wv_prefilter, wv_data, nx, ny, cavity, header)
#     115     else:
#     116         p = interpolate(np.expand_dims(coeff, (-1,-2)), wv_prefilter, np.expand_dims(wv - crop(cavity, header=header), (0,1)))[0]
# --> 117     q = polyval2d(x, y, p)
#     118     prefilter.append(q)
#     119 return np.array(prefilter)
#
# File ~/PycharmProjects/flatfield/src/prefilter_correction.py:77, in polyval2d(x, y, p)
#      75 def polyval2d(x, y, p):
#      76     degree = int((np.sqrt(8 * len(p) + 1) - 3) / 2)
# ---> 77     return np.sum([p_ * x_ for p_, x_ in zip(p, polyterms2d(x, y, degree=degree))], axis=0)
#
# File ~/PycharmProjects/flatfield/src/prefilter_correction.py:72, in polyterms2d(x, y, degree)
#      70     return [np.ones_like(x)]
#      71 else:
# ---> 72     return np.append(polyterms2d(x, y, degree=degree-1), np.array([x ** (degree - i) * y ** i for i in range(degree + 1)]), axis=0)
#
# File ~/PycharmProjects/flatfield/src/prefilter_correction.py:72, in <listcomp>(.0)
#      70     return [np.ones_like(x)]
#      71 else:
# ---> 72     return np.append(polyterms2d(x, y, degree=degree-1), np.array([x ** (degree - i) * y ** i for i in range(degree + 1)]), axis=0)
#
# KeyboardInterrupt:
