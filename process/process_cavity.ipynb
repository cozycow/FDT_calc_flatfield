# %%
from calc_cavity import calc_cavity
import glob

# %%
dark_file = '/home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz'
deadpix_file = '/home/ulyanov/data/solo/phi/dead_pixels/phi-fdt-deadpix_20250915T140003_V202609041736C_0569150100.fits'
prefilter_file = '/home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt'
distortion_file = '/home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz'

# %%
flat_files = sorted(glob.glob('/home/ulyanov/data/solo/phi/flat/temp/*flat*.fits'))
ghost_files = sorted(glob.glob('/home/ulyanov/data/solo/phi/flat/temp/*ghost*.fits'))
flat_dids = [flat_file.split('_')[-1].split('.')[0] for flat_file in flat_files]
ghost_dids = [ghost_file.split('_')[-1].split('.')[0] for ghost_file in ghost_files]
flat_files
# Out:
# ['/home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20240330T050009_V202608262158C_0463300100.fits',
#  '/home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20240926T114503_V202608262134C_0469260100.fits',
#  '/home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20241016T113003_V202608262111C_0470160100.fits',
#  '/home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20241027T233003_V202608262048C_0470270100.fits',
#  '/home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20241202T123003_V202608262027C_0472020100.fits',
#  '/home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20250119T210009_V202608262003C_0561190100.fits',
#  '/home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20250310T080009_V202608261939C_0563100100.fits',
#  '/home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20250915T140003_V202608261916C_0569150100.fits',
#  '/home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20250923T000503_V202608261853C_0569230100.fits',
#  '/home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20260310T040003_V202608261828C_0663100100.fits',
#  '/home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20260425T230003_V202608261804C_0664250100.fits']

# %%
folders = sorted(glob.glob('/home/ulyanov/data/solo/phi/flat/fdt/calibration/*'))[::-1]
folders
# Out:
# ['/home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-12-02',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-27',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-10-16',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-09-26',
#  '/home/ulyanov/data/solo/phi/flat/fdt/calibration/2024-03-30']

# %%
for folder in folders[:]:
    files = sorted(glob.glob(folder + '/*.fits.gz'))
    did = files[0].split('_')[-1].split('.')[0]

    flat_file = flat_files[flat_dids.index(did)]
    ghost_file = ghost_files[ghost_dids.index(did)]

    calc_cavity(folder, 'temp',
               dark_file=dark_file,
               deadpix_file=deadpix_file,
               flatfield_file=flat_file,
               ghost_file=ghost_file,
               prefilter_file=prefilter_file,
               distortion_file=distortion_file,
               niter=1000,
               quicklook=False)
# Out:
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T230003_V202605051433C_0664250100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T233204_V202605201634C_0664250300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/phi-fdt-deadpix_20250915T140003_V202609041457C_0569150100.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# flatfield file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20260425T230003_V202608261804C_0664250100.fits
# ghost file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-ghost_20260425T230003_V202608261804C_0664250100.fits
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.80967238 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 61 C
# continuum position is: blue
# /home/ulyanov/PycharmProjects/flatfield/src/fit_pv.py:16: RuntimeWarning: invalid value encountered in divide
#   f_ = (f_ - af) / bf
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T230003_V202605051433C_0664250100.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T230404_V202605051633C_0664250125.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T230804_V202605051733C_0664250150.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T231204_V202605121034C_0664250175.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T231604_V202605121135C_0664250200.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T232004_V202605121135C_0664250225.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T232404_V202605201333C_0664250250.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T232804_V202605201634C_0664250275.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-04-25/solo_L1_phi-fdt-ilam_20260425T233204_V202605201634C_0664250300.fits.gz processed
# disk centers are: [[ 999.7155 1039.7689]
#  [ 934.2867  988.3138]
#  [ 970.6221 1016.9588]
#  [1019.2684 1054.9848]
#  [1111.2405 1126.9136]
#  [ 948.7359 1104.944 ]
#  [ 977.4759 1068.5888]
#  [1015.639  1019.7559]
#  [1087.1212  928.3869]]
# calculating mask
# calculating cavity
# /home/ulyanov/PycharmProjects/flatfield/src/kll.py:60: RuntimeWarning: divide by zero encountered in divide
#   A += np.nan_to_num((y - A) * w / W)
# /home/ulyanov/PycharmProjects/flatfield/src/kll.py:60: RuntimeWarning: overflow encountered in multiply
#   A += np.nan_to_num((y - A) * w / W)
# /home/ulyanov/PycharmProjects/flatfield/src/kll.py:61: RuntimeWarning: divide by zero encountered in divide
#   B += np.nan_to_num((x - B) * w / W)
# distorting cavity
# saving result
# cavity map saved to file: temp/phi-fdt-cavity_20260425T230003_V202609041548C_0664250100.fits
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T040003_V202606241235C_0663100100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T043205_V202606241634C_0663100300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/phi-fdt-deadpix_20250915T140003_V202609041457C_0569150100.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# flatfield file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20260310T040003_V202608261828C_0663100100.fits
# ghost file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-ghost_20260310T040003_V202608261828C_0663100100.fits
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.32765725 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 66 C
# continuum position is: blue
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T040003_V202606241235C_0663100100.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T040405_V202606241235C_0663100125.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T040805_V202606241336C_0663100150.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T041205_V202606241336C_0663100175.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T041605_V202606241434C_0663100200.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T042005_V202606241434C_0663100225.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T042405_V202606241535C_0663100250.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T042805_V202606241634C_0663100275.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2026-03-10/solo_L1_phi-fdt-ilam_20260310T043205_V202606241634C_0663100300.fits.gz processed
# disk centers are: [[ 996.4155 1048.7951]
#  [ 834.6281  921.768 ]
#  [ 924.4162  992.0576]
#  [1044.9541 1086.6404]
#  [1271.6998 1264.2965]
#  [ 869.5044 1209.9033]
#  [ 940.2657 1120.3262]
#  [1035.1377  999.7168]
#  [1212.7919  772.9717]]
# calculating mask
# calculating cavity
# distorting cavity
# saving result
# cavity map saved to file: temp/phi-fdt-cavity_20260310T040003_V202609041610C_0663100100.fits
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T000503_V202512011636C_0569230100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T005305_V202511220034C_0569230300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/phi-fdt-deadpix_20250915T140003_V202609041457C_0569150100.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# flatfield file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20250923T000503_V202608261853C_0569230100.fits
# ghost file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-ghost_20250923T000503_V202608261853C_0569230100.fits
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.33117085 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 66 C
# continuum position is: blue
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T000503_V202512011636C_0569230100.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T001105_V202511212307C_0569230125.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T001705_V202511212307C_0569230150.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T002305_V202511212307C_0569230175.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T002905_V202511212307C_0569230200.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T003505_V202511212307C_0569230225.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T004105_V202511212338C_0569230250.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T004705_V202511220034C_0569230275.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-23/solo_L1_phi-fdt-ilam_20250923T005305_V202511220034C_0569230300.fits.gz processed
# disk centers are: [[1005.441  1043.5451]
#  [ 845.1299  917.9931]
#  [ 934.5483  988.2131]
#  [1054.3536 1082.1277]
#  [1277.9893 1257.5459]
#  [ 880.0873 1203.7787]
#  [ 949.8945 1114.91  ]
#  [1043.6995  995.6036]
#  [1219.3822  771.8683]]
# calculating mask
# calculating cavity
# /home/ulyanov/PycharmProjects/flatfield/src/kll.py:61: RuntimeWarning: overflow encountered in multiply
#   B += np.nan_to_num((x - B) * w / W)
# distorting cavity
# saving result
# cavity map saved to file: temp/phi-fdt-cavity_20250923T000503_V202609041631C_0569230100.fits
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T140003_V202511211337C_0569150100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T144807_V202511212307C_0569150300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/phi-fdt-deadpix_20250915T140003_V202609041457C_0569150100.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# flatfield file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20250915T140003_V202608261916C_0569150100.fits
# ghost file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-ghost_20250915T140003_V202608261916C_0569150100.fits
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.29446903 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 61 C
# continuum position is: blue
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T140003_V202511211337C_0569150100.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T140607_V202511211437C_0569150125.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T141207_V202511211437C_0569150150.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T141807_V202511211437C_0569150175.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T142407_V202511212307C_0569150200.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T143007_V202511212307C_0569150225.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T143607_V202511212307C_0569150250.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T144207_V202511212307C_0569150275.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-09-15/solo_L1_phi-fdt-ilam_20250915T144807_V202511212307C_0569150300.fits.gz processed
# disk centers are: [[1002.7267 1049.1417]
#  [ 822.7891  907.7911]
#  [ 923.2417  986.4005]
#  [1057.6557 1091.7564]
#  [1309.6947 1289.8508]
#  [ 861.6536 1228.7346]
#  [ 940.5543 1128.6036]
#  [1046.2539  994.1651]
#  [1244.1375  742.1405]]
# calculating mask
# calculating cavity
# distorting cavity
# saving result
# cavity map saved to file: temp/phi-fdt-cavity_20250915T140003_V202609041653C_0569150100.fits
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T080009_V202503131733C_0563100100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T084808_V202503141833C_0563100300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/phi-fdt-deadpix_20250915T140003_V202609041457C_0569150100.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# flatfield file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20250310T080009_V202608261939C_0563100100.fits
# ghost file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-ghost_20250310T080009_V202608261939C_0563100100.fits
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.50961276 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 56 C
# continuum position is: red
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T080009_V202503131733C_0563100100.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T080608_V202503131733C_0563100125.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T081208_V202503131835C_0563100150.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T081808_V202503131935C_0563100175.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T082408_V202503131935C_0563100200.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T083008_V202503132033C_0563100225.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T083608_V202503141634C_0563100250.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T084208_V202503141734C_0563100275.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-03-10/solo_L1_phi-fdt-ilam_20250310T084808_V202503141833C_0563100300.fits.gz processed
# disk centers are: [[ 993.7571 1033.392 ]
#  [ 889.8589  951.7058]
#  [ 947.9207  997.2205]
#  [1025.6976 1058.2382]
#  [1170.8089 1171.8953]
#  [ 912.2233 1136.8719]
#  [ 958.0921 1079.3093]
#  [1019.1751 1001.485 ]
#  [1133.1592  856.4104]]
# calculating mask
# calculating cavity
# distorting cavity
# saving result
# cavity map saved to file: temp/phi-fdt-cavity_20250310T080009_V202609041715C_0563100100.fits
# done
# looking for files in folder: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19
# found 9 input files
# first input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19/solo_L1_phi-fdt-ilam_20250119T210009_V202501210811C_0561190100.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19/solo_L1_phi-fdt-ilam_20250119T213207_V202501210811C_0561190300.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# dead pixels file is: /home/ulyanov/data/solo/phi/dead_pixels/phi-fdt-deadpix_20250915T140003_V202609041457C_0569150100.fits
# prefilter file is: /home/ulyanov/data/solo/phi/prefilter/phi-fdt-prefilter_20250916T023002_V202607231634C_0569160250.txt
# flatfield file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-flat_20250119T210009_V202608262003C_0561190100.fits
# ghost file is: /home/ulyanov/data/solo/phi/flat/temp/phi-fdt-ghost_20250119T210009_V202608262003C_0561190100.fits
# distortion file is: /home/ulyanov/data/solo/phi/distortion/fdt/distortion_cor.npz
# distance is: 0.9152812 AU
# PMP SP temperature is: 45 C
# FG SP temperature is: 61 C
# continuum position is: red
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19/solo_L1_phi-fdt-ilam_20250119T210009_V202501210811C_0561190100.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19/solo_L1_phi-fdt-ilam_20250119T210407_V202501210811C_0561190125.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19/solo_L1_phi-fdt-ilam_20250119T210807_V202501210811C_0561190150.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19/solo_L1_phi-fdt-ilam_20250119T211207_V202501210811C_0561190175.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19/solo_L1_phi-fdt-ilam_20250119T211607_V202501210811C_0561190200.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19/solo_L1_phi-fdt-ilam_20250119T212007_V202501210811C_0561190225.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19/solo_L1_phi-fdt-ilam_20250119T212407_V202501210811C_0561190250.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19/solo_L1_phi-fdt-ilam_20250119T212807_V202501210811C_0561190275.fits.gz processed
# file /home/ulyanov/data/solo/phi/flat/fdt/calibration/2025-01-19/solo_L1_phi-fdt-ilam_20250119T213207_V202501210811C_0561190300.fits.gz processed
# disk centers are: [[ 999.0669 1035.1828]
#  [ 940.9531  989.7473]
#  [ 972.9852 1014.9828]
#  [1016.5718 1049.0188]
#  [1097.3447 1112.4806]
#  [ 953.5317 1092.7371]
#  [ 978.983  1060.5584]
#  [1012.7814 1017.2437]
#  [1075.7897  936.5167]]
# calculating mask
# calculating cavity
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       5 flat_file = flat_files[flat_dids.index(did)]
#       6 ghost_file = ghost_files[ghost_dids.index(did)]
# ----> 8 calc_cavity(folder, 'temp',
#       9            dark_file=dark_file,
#      10            deadpix_file=deadpix_file,
#      11            flatfield_file=flat_file,
#      12            ghost_file=ghost_file,
#      13            prefilter_file=prefilter_file,
#      14            distortion_file=distortion_file,
#      15            niter=100,
#      16            quicklook=False)
#
# File ~/PycharmProjects/flatfield/src/calc_cavity.py:155, in calc_cavity(files, folder_out, dark_file, deadpix_file, prefilter_file, flatfield_file, ghost_file, distortion_file, niter, quicklook, verbose)
#     151     print('calculating cavity')
#     153 cavity_lcp = kll(np.nan_to_num(vlcps), centers, weights=np.nan_to_num(weights),
#     154                  niter=niter, sigma=1e-3, vmin=-0.2, vmax=0.2)
# --> 155 cavity_rcp = kll(np.nan_to_num(vrcps), centers, weights=np.nan_to_num(weights),
#     156                  niter=niter, sigma=1e-3, vmin=-0.2, vmax=0.2)
#     158 cavity = np.array([cavity_lcp, cavity_rcp])
#     159 cavity[:,mask] = np.nan
#
# File ~/PycharmProjects/flatfield/src/kll.py:16, in kll(datas, shifts, weights, niter, sigma, vmin, vmax, slope, **kwargs)
#      13     F = np.zeros_like(datas[0])
#      15 for iter in range(niter):
# ---> 16     D = step(forward(datas, shifts, weights, F, **kwargs), slope=slope)
#      17     F = step(backward(datas, shifts, weights, D, **kwargs), slope=slope, guess=F, sigma=sigma).clip(vmin, vmax)
#      18 return F
#
# File ~/PycharmProjects/flatfield/src/kll.py:61, in step(data, slope, guess, sigma)
#      59     else:
#      60         A += np.nan_to_num((y - A) * w / W)
# ---> 61         B += np.nan_to_num((x - B) * w / W)
#      63 if slope:
#      64     return np.nan_to_num(A / B)
#
# KeyboardInterrupt:

# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from scipy.ndimage import gaussian_filter
from fitting import *

file = 'temp/phi-fdt-cavity_20260310T040003_V202609041314C_0663100100.fits'

with fits.open(file) as hdul:
    data = hdul[0].data
    header = hdul[0].header

# %%
temp = data[0] - data[1]
fit = gaussian_filter(temp, 50)
#temp[np.abs(temp) < 1e-8] = np.nan
#fit = polyfit2d(temp, degree=3)

# %%
plt.figure(figsize=(10,10))
plt.imshow(fit, 'seismic', vmin=-1e-4, vmax=1e-4)
plt.tight_layout()

# %%
np.savez('/home/ulyanov/data/solo/bias.npz', bias=fit)

# %%
q_V = 299792458 / 6173.341

10 / q_V

# %%
q = data[0].copy()

# %%
plt.figure(figsize=(10,10))
plt.imshow(q - data[0], 'seismic', vmin=-1e-2, vmax=1e-2)
plt.tight_layout()
