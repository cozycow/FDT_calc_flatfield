# %%
from calc_prefilter import calc_prefilter

# %%
dark_file = '/home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz'

# %%
folder = '/home/ulyanov/data/solo/phi/prefilter/calibration/2025-09-16/'

# %%
calc_prefilter(folder, '', dark_file=dark_file)
# Out:
# looking for files in folder: /home/ulyanov/data/solo/phi/prefilter/calibration/2025-09-16/
# found 3 input files
# first input file is: /home/ulyanov/data/solo/phi/prefilter/calibration/2025-09-16/solo_CAL1_phi-fdt-wavescan_20250916T023002_V202604242047C_0569160250.fits.gz
# last input file is: /home/ulyanov/data/solo/phi/prefilter/calibration/2025-09-16/solo_CAL1_phi-fdt-wavescan_20250916T133003_V202604242101C_0569160252.fits.gz
# reading and preprocessing the data
# dark signal file is: /home/ulyanov/data/solo/phi/dark/solo_CAL1_phi-fdt-dark_20240205T033810_V202402220119C_0422051001.fits.gz
# temperatures are: [61.0, 66.0, 55.99]
# velocities are: [-69.9515603852687, 805.734768504672, 1305.12722331006]
# fitting the line profile
# removing the line and averaging
# normalizing the prefilter
# fitting the prefilter with 2d-polynomial
# writing prefilter file
# done
