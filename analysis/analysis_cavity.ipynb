# %%
# %matplotlib qt
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
from scipy.ndimage import gaussian_filter
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.

# %%
files = sorted(glob.glob('../process/temp/*cavity*.fits'))
files
# Out:
# ['../process/temp/phi-fdt-cavity_20250310T080009_V202609041715C_0563100100.fits',
#  '../process/temp/phi-fdt-cavity_20250915T140003_V202609041653C_0569150100.fits',
#  '../process/temp/phi-fdt-cavity_20250923T000503_V202609041631C_0569230100.fits',
#  '../process/temp/phi-fdt-cavity_20260310T040003_V202609041610C_0663100100.fits',
#  '../process/temp/phi-fdt-cavity_20260425T230003_V202609041548C_0664250100.fits']

# %%
cavities = []

for file in files:
    with fits.open(file) as hdul:
        data = hdul[0].data

    cavities.append(data)

cavities = np.array(cavities)

# %%
cavities.shape
# Out:
# (5, 2, 2048, 2048)

# %%
plt.figure(figsize=(10,10))
plt.imshow(cavities[0,0], 'seismic', vmin=-0.07, vmax=0.07)
plt.tight_layout()

# %%
plt.figure(figsize=(10,10))
plt.imshow(cavities[2,0] - cavities[1,0], 'seismic', vmin=-0.01, vmax=0.01)
plt.tight_layout()

# %%
temp = cavities[2,0] - cavities[2,1]
temp -= np.nanmean(temp[750:1250,750:1250])

plt.figure(figsize=(10,10))
plt.imshow(gaussian_filter(temp, 50), 'seismic', vmin=-1e-4, vmax=1e-4)
plt.tight_layout()
